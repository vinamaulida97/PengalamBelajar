# %% [markdown]
# <a href="https://colab.research.google.com/github/vinamaulida97/PengalamBelajar/blob/main/coba_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_excel('sianida_excel.xlsx')

# %%
data.head(10)
# Out:
#                                              Column1  \
# 0  created_at;id_str;full_text;quote_count;reply_...
# 1  Wed Nov 01 12:23:54 +0000 2023;171969173473584...
# 2  Wed Nov 01 12:18:11 +0000 2023;171969029447899...
# 3  Wed Nov 01 12:09:52 +0000 2023;171968820219653...
# 4  Wed Nov 01 11:58:48 +0000 2023;171968541681374...
# 5  Wed Nov 01 11:54:04 +0000 2023;171968422615156...
# 6  Wed Nov 01 11:32:19 +0000 2023;171967875447220...
# 7  Wed Nov 01 10:56:16 +0000 2023;171966968234373...
# 8  Wed Nov 01 10:54:31 +0000 2023;171966923873728...
# 9  Wed Nov 01 10:32:49 +0000 2023;171966377855461...
#
#                                             komentar
# 0                                                NaN
# 1                                                NaN
# 2   ak ldr nder(^_^)";0;1;0;0;in;8553281028172144...
# 3                                                NaN
# 4   pengen ku sianida orgnya";0;0;0;0;in;12345498...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9   atau minimal bantuin nanem pohon ghorgot"  Ot...

# %%
data.dropna(inplace=True)

# %%
data.dropna(axis=1, inplace=True)

# %%
data.head(10)
# Out:
#                                               Column1  \
# 2   Wed Nov 01 12:18:11 +0000 2023;171969029447899...
# 4   Wed Nov 01 11:58:48 +0000 2023;171968541681374...
# 9   Wed Nov 01 10:32:49 +0000 2023;171966377855461...
# 10  Wed Nov 01 10:32:40 +0000 2023;171966374082690...
# 11  Wed Nov 01 09:59:08 +0000 2023;171965530251641...
# 15  Wed Nov 01 08:08:59 +0000 2023;171962758301972...
# 16  Wed Nov 01 07:07:53 +0000 2023;171961220682285...
# 17  Wed Nov 01 07:05:05 +0000 2023;171961149984357...
# 18  Wed Nov 01 07:04:42 +0000 2023;171961140376886...
# 23  Wed Nov 01 05:04:14 +0000 2023;171958108966327...
#
#                                              komentar
# 2    ak ldr nder(^_^)";0;1;0;0;in;8553281028172144...
# 4    pengen ku sianida orgnya";0;0;0;0;in;12345498...
# 9    atau minimal bantuin nanem pohon ghorgot"  Ot...
# 10   bayar netplix bulan ini cuma dipake dr stone ...
# 11   ak mau heheh";0;0;0;1;in;855328102817214472;1...
# 15   00  Jual kopi sianida ga bang?";0;0;0;0;in;13...
# 16   semua akan koplo pada waktunyaaaaa~aaah!";0;0...
# 17   Paduka Ratu teh dokter. Asa ingetnya cuma bat...
# 18   kalau nasi nya dicampur sianida";0;0;0;0;in;1...
# 23   contohnya kasus tahun 2016 tentang kopi siani...

# %%
data.to_excel('dataset_cleaned.xlsx', index=False)

# %%
#-- CASE FOLDING --
import string
import re #regex library

data['komentar'] = data['komentar'].str.lower()

def casef(text):
    # remove tab, new line, ans back slice
    #text = text.replace('\t'," ").replace('\n'," ").replace('\u'," ").replace('\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    text= text.replace("http://", " ").replace("https://", " ")
    #remove number
    text = re.sub(r"\d+", "", text)
    #remove punctuation/tanda baca
    text = text.translate(str.maketrans("","",string.punctuation))
    #remove whitespace leading & trailing/ spasi
    text = text.strip()
    #remove multiple whitespace into single whitespace
    text = re.sub('\s+',' ',text)
    return text

data['casefold'] = data['komentar'].apply(casef)
hasil_casefolding= data['casefold']
hasil_casefolding
# Out:
# 2                                   ak ldr nderinakuakuan
# 4                     pengen ku sianida orgnyainrenggaefr
# 9       atau minimal bantuin nanem pohon ghorgot otak ...
# 10      bayar netplix bulan ini cuma dipake dr stone s...
# 11                                 ak mau hehehinakuakuan
#                               ...
# 1491                    tinggal sabar menantiinrajatapura
# 1493    kisruh kasus sianida dianalisa dokter lain lew...
# 1498    tiktok saya cape ngebatin terus sama tuh jaksa...
# 1499    masak iya masukin sianida ke dalam jus apa gak...
# 1503    mg kenapa ga disemprot aja semua pikirrr logik...
# Name: casefold, Length: 556, dtype: object

# %%
# ------ Tokenizing ---------
import nltk
nltk.download('punkt')
# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize

# NLTK word tokenize
def word_tokenize_wrapper(text):
  return word_tokenize(text)

data['komen_tokens'] = data['casefold'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n')
print(data['komen_tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 2                             [ak, ldr, nderinakuakuan]
# 4              [pengen, ku, sianida, orgnyainrenggaefr]
# 9     [atau, minimal, bantuin, nanem, pohon, ghorgot...
# 10    [bayar, netplix, bulan, ini, cuma, dipake, dr,...
# 11                           [ak, mau, hehehinakuakuan]
# Name: komen_tokens, dtype: object
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#-- STOPWORDS REMOVAL --
list_stopwords = {"adalah","akan","akhir","aku","saya","antara","antaranya","apabila","atau","bahwa","bahwasannya","berikut","berkata","berupa","dan","dalam","dapat","dari","demikian","dengan","di","dia","beliau","mas","pak","diri","dirinya","guna","hal","hingga","ia","ialah","ibarat","ibaratnya","ibu","ingin","inginkan","ini","itu","jadi","kami","kalian","kamu","kan","karena","kini","lalu","kita","maka","mereka","merupakan","misal","misalkan","misalnya","pertama","orang","pada","nya","saat","sendiri","sini","yaitu","yang","kalau","jika","untuk","secara","sedangkan","luar","alangkah","wkkk",
                  "wkwkw","wkwkwkw","wk","wkkw"}

list_stopwords = set(list_stopwords)

#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

data['komen_filtered'] = data['komen_tokens'].apply(stopwords_removal)

print(data['komen_filtered'].head())
# Out:
# 2                             [ak, ldr, nderinakuakuan]
# 4              [pengen, ku, sianida, orgnyainrenggaefr]
# 9     [minimal, bantuin, nanem, pohon, ghorgot, otak...
# 10    [bayar, netplix, bulan, cuma, dipake, dr, ston...
# 11                           [ak, mau, hehehinakuakuan]
# Name: komen_filtered, dtype: object

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
for document in data['komen_filtered']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

data['komen_stemmed'] = data['komen_filtered'].apply(get_stemmed_term)
print(data['komen_stemmed'].tail(10))
# Out:
# 1482      [nyimak, pjlsan, dr, djaja, yg, pakar, sianida]
# 1484    [bukan, menit, telah, tinggal, priksa, negatif...
# 1485                                      [kopi, sianida]
# 1486    [adolf, hitler, sampai, puja, sekte, intempodo...
# 1488    [aja, logika, ga, jalas, ada, pura, kenapa, st...
# 1491                [tinggal, sabar, menantiinrajatapura]
# 1493    [kisruh, kasus, sianida, dianalisa, dokter, la...
# 1498    [tiktok, cape, ngebatin, terus, sama, tuh, jak...
# 1499    [masak, iya, masukin, sianida, ke, jus, apa, g...
# 1503    [mg, kenapa, ga, semprot, aja, semua, pikirrr,...
# Name: komen_stemmed, dtype: object

# %%
#install scikit-learn library
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.3.2

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer

# %%
max_features = 1000
databaru= data['komen_stemmed'].astype(str)

#menambahkan ngram=(1,2) dst kalo mau pake pemisahan per 2 kata atau lebih
cvect = CountVectorizer(max_features=max_features, ngram_range=(1,3), binary=True)
TF_vector = cvect.fit_transform(databaru)

# hitung TF
tfidf_matt = cvect.fit_transform(databaru).toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-268490520e44> in <cell line: 2>()
#       1 max_features = 1000
# ----> 2 databaru= data['komen_stemmed'].astype(str)
#       3
#       4 #menambahkan ngram=(1,2) dst kalo mau pake pemisahan per 2 kata atau lebih
#       5 cvect = CountVectorizer(max_features=max_features, ngram_range=(1,3), binary=True)
#
# NameError: name 'data' is not defined
